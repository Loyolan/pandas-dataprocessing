# %%
import pandas as pd

data = pd.read_csv('netflix-dataset/data.csv')
data.shape
# Out:
# (1000, 10)

# %%
data
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
data.columns
# Out:
# Index(['id', 'date', 'first_name', 'last_name', 'email', 'gender',
#        'ip_address', 'country', 'price_paid', 'tax'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df = data.set_index('email')
df
# Out:
#                               id        date first_name   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021    Marylin      Alders    Male
# hharridge1@gnu.org             2  03/19/2021      Hinda    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021        Erl  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Grata      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021      Kanya     Beasant    Male
# ...                          ...         ...        ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021       Duff      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021        Ame     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021      Betty    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021    Paquito       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021   Rochelle    Pringuer     NaN
#
# ...

# %%
df.loc['malders0@shop-pro.jp'].values
# Out:
# array([1, '03/28/2021', 'Marylin', 'Alders', 'Male', '160.119.8.119',
#        'Canada', '$5.36', nan], dtype=object)

# %%
data['gender'] == 'Male'
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997     True
# 998     True
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
data[data['gender'] == 'Male']
# Out:
#       id        date first_name   last_name                       email  \
# 0      1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7      8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8      9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..   ...         ...        ...         ...                         ...
# 991  992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 992  993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me
# 993  994  03/22/2021      Ossie      Snelle            osnellerl@nhs.uk
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998  999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
#
#     gender       ip_address        country price_paid   tax
# ...

# %%
df_f = data['gender'] == 'Female'
data[df_f]
# Out:
#       id        date first_name   last_name                       email  \
# 1      2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 5      6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# 6      7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# 12    13  03/05/2021     Janice    Morillas  jmorillasc@miibeian.gov.cn
# ..   ...         ...        ...         ...                         ...
# 985  986  03/29/2021     Yvonne  Longworthy       ylongworthyrd@163.com
# 988  989  03/07/2021       Yves      Botler  ybotlerrg@miitbeian.gov.cn
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995  996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996  997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
#
#      gender      ip_address        country price_paid   tax
# ...

# %%
df_fc = data['country'].isin(['France', 'Canada'])
data[df_fc]
# Out:
#        id        date first_name   last_name                      email  \
# 0       1  03/28/2021    Marylin      Alders       malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge         hharridge1@gnu.org
# 6       7  03/14/2021        Ava     Kencott         akencott6@phoca.cz
# 7       8  03/08/2021       Codi     Feasley           cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema      wheersema8@tumblr.com
# ..    ...         ...        ...         ...                        ...
# 992   993  03/04/2021    Maurene  Guilloneau     mguilloneaurk@about.me
# 993   994  03/22/2021      Ossie      Snelle           osnellerl@nhs.uk
# 994   995  03/17/2021   Carolyne    Bruntjen  cbruntjenrm@reference.com
# 995   996  03/24/2021       Duff      Errigo       derrigorn@elpais.com
# 999  1000  03/23/2021   Rochelle    Pringuer      rpringuerrr@house.gov
#
#      gender      ip_address country price_paid   tax
# ...

# %%
# CHANGE PRICE TO INT
data.price_paid = data.price_paid.apply(lambda x: x.replace("$", ""))
data.price_paid = data.price_paid.astype(float)
data
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...

# %%
d = data.copy()
d.gender = d.gender.apply(lambda x: '0' if x == 'Female' else '1')
d.gender = d.gender.astype(int)
d.head(20)
# Out:
#     id        date first_name   last_name                       email  gender  \
# 0    1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp       1
# 1    2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org       0
# 2    3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com       1
# 3    4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu       0
# 4    5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com       1
# 5    6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu       0
# 6    7  03/14/2021        Ava     Kencott          akencott6@phoca.cz       0
# 7    8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov       1
# 8    9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com       1
# 9   10  03/23/2021  Guglielma      Gookes       ggookes9@amazon.co.uk       1
# 10  11  03/11/2021       Lief   Woodcraft   lwoodcrafta@sitemeter.com       1
# ...

# %%
# SUPPRIMER UNE COLONE
data.drop('ip_address', axis=1)
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender        country  price_paid   tax
# 0      Male         Canada        5.36   NaN
# ...

# %%
data.drop(['first_name', 'last_name', 'email'], axis=1)
# Out:
#        id        date  gender       ip_address        country  price_paid  \
# 0       1  03/28/2021    Male    160.119.8.119         Canada        5.36
# 1       2  03/19/2021  Female   210.51.172.132         Canada        8.32
# 2       3  03/17/2021    Male    213.8.101.145  United States        3.73
# 3       4  03/19/2021  Female    5.140.237.101  United States        3.70
# 4       5  03/24/2021    Male  106.252.162.233        Morocco        9.24
# ..    ...         ...     ...              ...            ...         ...
# 995   996  03/24/2021  Female   193.84.247.144         France        3.63
# 996   997  03/17/2021  Female   188.219.12.109            NaN        4.59
# 997   998  03/13/2021    Male     199.80.60.87  United States        7.54
# 998   999  03/17/2021    Male      0.183.63.11  United States        5.81
# 999  1000  03/23/2021     NaN   170.193.249.83         Canada        8.01
#
#       tax
# 0     NaN
# 1     NaN
# 2    20.0
# 3    20.0
# 4    20.0
# ...

# %%
del df['first_name']
df
# Out:
#                               id        date   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021      Alders    Male
# hharridge1@gnu.org             2  03/19/2021    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021     Beasant    Male
# ...                          ...         ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021    Pringuer     NaN
#
#                                  ip_address        country price_paid   tax
# email
# malders0@shop-pro.jp          160.119.8.119         Canada      $5.36   NaN
# ...

# %%
data.isnull()
# Out:
#         id   date  first_name  last_name  email  gender  ip_address  country  \
# 0    False  False       False      False  False   False       False    False
# 1    False  False       False      False  False   False       False    False
# 2    False  False       False      False  False   False       False    False
# 3    False  False       False      False  False   False       False    False
# 4    False  False       False      False  False   False       False    False
# ..     ...    ...         ...        ...    ...     ...         ...      ...
# 995  False  False       False      False  False   False       False    False
# 996  False  False       False      False  False   False       False     True
# 997  False  False       False      False  False   False       False    False
# 998  False  False       False      False  False   False       False    False
# 999  False  False       False      False  False    True       False    False
#
#      price_paid    tax
# ...

# %%
# SHOW ALL NAN IN TAX
data[data['tax'].isnull()]
# Out:
#       id        date first_name   last_name                   email  gender  \
# 0      1  03/28/2021    Marylin      Alders    malders0@shop-pro.jp    Male
# 1      2  03/19/2021      Hinda    Harridge      hharridge1@gnu.org  Female
# 5      6  03/25/2021      Titos  Braybrooke    tbraybrooke5@umn.edu  Female
# 6      7  03/14/2021        Ava     Kencott      akencott6@phoca.cz  Female
# 9     10  03/23/2021  Guglielma      Gookes   ggookes9@amazon.co.uk    Male
# ..   ...         ...        ...         ...                     ...     ...
# 985  986  03/29/2021     Yvonne  Longworthy   ylongworthyrd@163.com  Female
# 992  993  03/04/2021    Maurene  Guilloneau  mguilloneaurk@about.me    Male
# 993  994  03/22/2021      Ossie      Snelle        osnellerl@nhs.uk    Male
# 995  996  03/24/2021       Duff      Errigo    derrigorn@elpais.com  Female
# 998  999  03/17/2021    Paquito       Tesoe  ptesoerq@rakuten.co.jp    Male
#
#          ip_address        country  price_paid  tax
# ...

# %%
data[data['tax'].notnull()]
# Out:
#        id        date first_name   last_name                       email  \
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7       8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..    ...         ...        ...         ...                         ...
# 991   992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...

# %%
# REMPLIR LE NaN
import numpy as np
data['tax'].fillna(np.mean(data['tax']))
# Out:
# 0      20.0
# 1      20.0
# 2      20.0
# 3      20.0
# 4      20.0
#        ...
# 995    20.0
# 996    20.0
# 997    20.0
# 998    20.0
# 999    20.0
# Name: tax, Length: 1000, dtype: float64

# %%
data
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...

# %%
# SUPPRIMER TOUT LES NaN
data.dropna()
# Out:
#       id        date first_name   last_name                       email  \
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7      8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8      9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..   ...         ...        ...         ...                         ...
# 988  989  03/07/2021       Yves      Botler  ybotlerrg@miitbeian.gov.cn
# 990  991  03/19/2021       Shep    Thorburn  sthorburnri@prnewswire.com
# 991  992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
#
#      gender       ip_address        country  price_paid   tax
# ...

# %%
# UNE COLONNE
data.dropna(subset=['tax', 'country'])
# Out:
#        id        date first_name   last_name                       email  \
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7       8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..    ...         ...        ...         ...                         ...
# 990   991  03/19/2021       Shep    Thorburn  sthorburnri@prnewswire.com
# 991   992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...

# %% [markdown]
# ### AJOUT DE COLONNE

# %%
data.dtypes
# Out:
# id              int64
# date           object
# first_name     object
# last_name      object
# email          object
# gender         object
# ip_address     object
# country        object
# price_paid    float64
# tax           float64
# dtype: object

# %%
df['test'] = 0
df['tax'].fillna(0, inplace=True)
df
# Out:
#                               id        date   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021      Alders    Male
# hharridge1@gnu.org             2  03/19/2021    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021     Beasant    Male
# ...                          ...         ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021    Pringuer     NaN
#
#                                  ip_address        country price_paid   tax  \
# email
# malders0@shop-pro.jp          160.119.8.119         Canada      $5.36   0.0
# ...

# %%
del df['test']
df
# Out:
#                               id        date   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021      Alders    Male
# hharridge1@gnu.org             2  03/19/2021    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021     Beasant    Male
# ...                          ...         ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021    Pringuer     NaN
#
#                                  ip_address        country price_paid   tax
# email
# malders0@shop-pro.jp          160.119.8.119         Canada      $5.36   0.0
# ...

# %%
df.price_paid = df.price_paid.apply(lambda x: x.replace("$", ""))
df.price_paid = df.price_paid.astype(float)
df
# Out:
#                               id        date   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021      Alders    Male
# hharridge1@gnu.org             2  03/19/2021    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021     Beasant    Male
# ...                          ...         ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021    Pringuer     NaN
#
#                                  ip_address        country  price_paid   tax
# email
# malders0@shop-pro.jp          160.119.8.119         Canada        5.36   0.0
# ...

# %%
df['price_total'] = df['price_paid'] * df['tax']
df
# Out:
#                               id        date   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021      Alders    Male
# hharridge1@gnu.org             2  03/19/2021    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021     Beasant    Male
# ...                          ...         ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021    Pringuer     NaN
#
#                                  ip_address        country  price_paid   tax  \
# email
# malders0@shop-pro.jp          160.119.8.119         Canada        5.36   0.0
# ...

# %%
# MAP
countries = {"Canada": "CA", "France": "FR", "United States": "US", "Morocco": "MR"}
df['country_code'] = df['country'].map(countries)
df
# Out:
#                               id        date   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021      Alders    Male
# hharridge1@gnu.org             2  03/19/2021    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021     Beasant    Male
# ...                          ...         ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021    Pringuer     NaN
#
#                                  ip_address        country  price_paid   tax  \
# email
# malders0@shop-pro.jp          160.119.8.119         Canada        5.36   0.0
# ...

# %%
data['price_paid'].describe()
# Out:
# count    1000.000000
# mean        6.461930
# std         2.061968
# min         3.000000
# 25%         4.620000
# 50%         6.415000
# 75%         8.232500
# max        10.000000
# Name: price_paid, dtype: float64

# %%
data['country'].unique()
# Out:
# array(['Canada', 'United States', 'Morocco', 'France', nan], dtype=object)

# %%
data['country'].value_counts()
# Out:
# France           408
# United States    333
# Canada           161
# Morocco           54
# Name: country, dtype: int64

# %%
data['country'].value_counts(normalize=True)
# Out:
# France           0.426778
# United States    0.348326
# Canada           0.168410
# Morocco          0.056485
# Name: country, dtype: float64

# %%
dc = data.groupby("country")
dc.sum()
# Out:
#                    id  price_paid     tax
# country
# Canada          70365     1017.45  2160.0
# France         214440     2619.61  5100.0
# Morocco         26591      362.97   780.0
# United States  168150     2183.67  4520.0

# %%
data.groupby(['gender', 'country']).mean()
# Out:
#                               id  price_paid   tax
# gender country
# Female Canada         461.472973    6.419324  20.0
#        France         512.648241    6.350352  20.0
#        Morocco        479.925926    7.024815  20.0
#        United States  487.282353    6.437118  20.0
# Male   Canada         406.000000    6.117467  20.0
#        France         534.928177    6.498950  20.0
#        Morocco        483.652174    6.146957  20.0
#        United States  525.284722    6.672500  20.0

# %%
data.groupby("country")["price_paid"].sum().plot.pie(figsize=[14, 5])
# Out:
# <AxesSubplot:ylabel='price_paid'>

# %%
data.groupby("date")["price_paid"].sum().plot(figsize=[14, 5])
# Out:
# <AxesSubplot:xlabel='date'>

# %%
data.groupby("country")["price_paid"].sum().plot.bar(figsize=[14, 5])
# Out:
# <AxesSubplot:xlabel='country'>
